# %% [markdown]
# **Author:** Charles Taylor
#
# **Email:** ctay22@lsuhsc.edu
#
# **Date:** 28JAN2025
#
# **Purpose:** Streaming data dashboard that pulls JSON packets from a MQTT server.  The hardware in this use case is a ESP32-S2 WROOM that is reading values from a thermocouple (via an MCP9600 QWIIC board). The data is transmitted in frames via JSON with each value having an associated timestamp of milliseconds from from the MCU was restarted.
#
# **Key notes for implementation:**
# 1.   network for this dashboard must not block port 1883
# 2.   mcu connects to a network called 'TaylorLab' with password of 'asdfghjkl'. iOS attaches [network name to phone name](https://support.apple.com/guide/iphone/change-the-name-of-your-iphone-iphf256af64f/ios).
# 3.   mcu emits a blinking blue light at 0.5Hz intervals when transmitting

# %%
# @title INITIALIZE LIBRARIES - RUN ON (RE)START ONLY

# !pip install streamz #https://hvplot.holoviz.org/user_guide/Streaming.html
# !pip install paho-mqtt #https://github.com/Gressling/examples/blob/master/08-3%20MQTT%20subscriber%20for%20Jupyter%20(paho).ipynb

import time
import datetime
import numpy as np
import pandas as pd
import holoviews as hv
import streamz
import streamz.dataframe
from IPython.display import clear_output
import matplotlib.pyplot as plt
from bokeh.plotting import figure,output_file,show
from bokeh.io import output_notebook
from bokeh.models import Range1d

from holoviews import opts
from holoviews.streams import Pipe, Buffer

hv.extension('bokeh')

# import paho.mqtt.client as mqttClient
from paho.mqtt import client as mqttClient
import ssl
import json
from pandas import json_normalize

from google.colab import drive
drive.mount('/content/drive')

# %env HV_DOC_HTML=true


print('Everything loaded ok')

#SOURCES:
#https://colab.research.google.com/github/holoviz-community/HoloViz_KDD2022/blob/main/05_Real_Time_Dashboard.ipynb#scrollTo=6cff8ac0
#from https://holoviews.org/user_guide/Streaming_Data.html
#https://github.com/Gressling/examples/blob/master/08-3%20MQTT%20subscriber%20for%20Jupyter%20(paho).ipynb
# Out:
# ...
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='ec33ddeb-3302-4ef8-99a6-eaf355967cb1'>
#   <div id="e99933e6-fdda-4a09-991d-88641aff36c8" data-root-id="ec33ddeb-3302-4ef8-99a6-eaf355967cb1" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# @title INITIALIZE FUNCTIONS - RUN ON (RE)START ONLY

#log function that will push out every action on the MQTT server (ONLY FOR DEBUG)
def on_log(client, userdata, level, buf):
  print( str(datetime.datetime.now()) + ": ",buf)


#subscribe handler
def on_message(client, userdata, message):

  #pull in the global data frame that is being concat
  global df_data

  #print ("Client received: " + str(message.topic))       #(ONLY FOR DEBUG)
  #print ("Message received: " + str(message.payload))    #(ONLY FOR DEBUG)

  df = pd.DataFrame(json.loads(str(message.payload, encoding='utf-8')))
  df = df.reindex(columns=['time', 'data', 'ambient','sensor']).sort_values(by=['time'],ignore_index=True)

  df_data = pd.concat([df_data, df], ignore_index=True)
  #print(df_data.tail(20))                                #(ONLY FOR DEBUG)



#connection handler
def on_connect(client, userdata, flags, reason_code, properties):
  if flags.session_present:
    print('Flags Present During On_Connect')
  if reason_code == 0:
    print('Broker On_Connect Successful')
  if reason_code > 0:
    print('Broker On_Connect Error')


print('Everything loaded ok')
# Out:
# Everything loaded ok

# %%
# @title A: Setup and Connect MQTT Client for Streaming


broker_address="test.mosquitto.org"
port = 1883
# user = "roger"            # Only for Secured MQTT Broker
# password = "password"     # Only for Secured MQTT Broker
MQTT_Topic = "thermal_exp/measurements"
# MQTT_Topic = "test/results" #legacy topic

df_data = pd.DataFrame({'time':[],'data':[],'ambient':[],'sensor':[]}, columns=['time', 'data', 'ambient','sensor'])

# client = mqttClient.Client(mqttClient.CallbackAPIVersion.VERSION1,"ColabViz")  #create new instance
client = mqttClient.Client(client_id="ColabViz",callback_api_version=mqttClient.CallbackAPIVersion.VERSION2)  #create new instance
client.on_connect = on_connect                      #attach function(s) to callback
client.on_message = on_message
#client.on_log = on_log                             #(ONLY FOR DEBUG)
#client.username_pw_set(user, password=password)    # Only for Secured MQTT Broker
client.connect(broker_address, port=port)

#fire up the MQTT monitoring loop but nothing in it until subscriptions are made
client.loop_start()

#create subscriptions to broker topics
client.subscribe(MQTT_Topic)    #Sensor data in JSON packets
#client.subscribe("test/info")      #Not implemented at this time; study header

print('Dataframe and MQTT Broker all ready to go')
print("Subscribed to {0}".format(MQTT_Topic))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-48cdaeba5012> in <cell line: 0>()
#       9 # MQTT_Topic = "test/results" #legacy topic
#      10
# ---> 11 df_data = pd.DataFrame({'time':[],'data':[],'ambient':[],'sensor':[]}, columns=['time', 'data', 'ambient','sensor'])
#      12
#      13 # client = mqttClient.Client(mqttClient.CallbackAPIVersion.VERSION1,"ColabViz")  #create new instance
#
# NameError: name 'pd' is not defined

# %%
# @title B: Get data and show streaming plot

#Make sure the connection to broker is alive
# while Connected != True:
#   time.sleep(0.1)




try:
  print('Starting capture on {0}'.format(MQTT_Topic))

  while True:
    time.sleep(1)
    clear_output(wait=True)
    df_data.tail(500).plot(x='time',y='data',figsize=(15,5))
    plt.ylim(10, 75)
    plt.ylabel("Temperature [C]")
    plt.xlabel("Time from Restart [ms]")
    plt.show()

except KeyboardInterrupt:
  print('-> Stop MQTT Loop and Disconnect Client')
  client.loop_stop()
  client.disconnect()

  print('-> Exited gracefully')
# Out:
# -> Stop MQTT Loop and Disconnect Client
# -> Exited gracefully

# %%
# @title C: Plot a Summary of the Data

output_notebook()

graph = figure(title="Summary of the Capture")

graph.line(source=df_data,x='time',y='data', color='red',legend_label='Thermocouple')
graph.line(source=df_data,x='time',y='ambient', color='blue',legend_label='Ambient')
graph.y_range = Range1d(10, 250)
graph.yaxis.axis_label = 'Temperature [C]'
graph.xaxis.axis_label = 'Time from Reset [ms]'
graph.height=600
graph.width=1200
show(graph)

#Sources:
#https://docs.bokeh.org/en/3.0.2/docs/user_guide/basic/axes.html
#https://programminghistorian.org/en/lessons/visualizing-with-bokeh
# Out:
#   <div id="b616ad22-2074-4994-8fa5-0d24e67225dd" data-root-id="7846a309-021d-43ec-935b-b432e61ac611" style="display: contents;"></div>

# %%
# @title D: Save Data to File in OneDrive

# PUT THE UNIQUE FILENAME HERE EACH TIME
StudyName='PiezoPorcine'

current_time = datetime.datetime.now().strftime("%Y%m%d_%H%M%S_")

FILENAME=StudyName+"_"+current_time

df_data.to_csv('/content/drive/My Drive/'+FILENAME+'.csv', index=False)



# del df_data
# Out:
# <MQTTErrorCode.MQTT_ERR_NO_CONN: 4>

# %%
# @title E: Cleanup for Next Run

# Stop MQTT Loop and disconnect client
client.loop_stop()
client.disconnect()

# Delete dataframe
del df_data
